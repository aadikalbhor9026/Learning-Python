# %%
#if-elif-else statement
Age = int(input("enter your Age:"))
if Age >= 18:
    print("you are adult eligible to vote")
elif Age <= 10:
    print("you are small kid cant vote")
else:
    print("you are teenager cant vote")
# Out:
# you are teenager cant vote

# %%
#if-else statement
Marks = int(input("enter your percentage"))
if Marks >=34:
    print("you are pass")
else:
    print("you are fail")
# Out:
# you are pass

# %%
#if statement
Year = int(input("enter your birth year:"))
if Year >= 2010:
    print("you are Gen Alpha")
# Out:
# you are Gen Alpha

# %%
#nested if statement
age = int(input("enter your age:"))
if age >= 18:
    print("you are adult")
    if age >= 60:
        print("you are senior citizen")
    else:
        print("you are not senior citizen")
else:
    print("you are not adult")
# Out:
# you are adult
# you are senior citizen

# %%
# while loop
i = 1
while i<=5:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# for loop statement
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# Nested for loop
for i in range(2):
    for j in range(2):
        print(i,j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1

# %%
# break statement
for i in range(1,6):
    if i == 5:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# continue statement
for i in range(1,6):
    if i == 4:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 5

# %%
# pass statement
for i in range(1,6):
    if i == 3:
         pass
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#input and output statement
name = input("enter your name:")
age = int(input("enter your age:"))
print("Hello,", name, "you are", age, "years old.")
# Out:
# Hello, Aadi you are 18 years old.

# %%
a = 10 
b = 5
c = a + b
print("c =", c)
# Out:
# c = 15

# %%
#arthmetic operators
x = 10
y = 5

print("addition:", x + y)
print("subtraction:", x - y)
print("multiplication:", x * y)
print("division:", x / y)
print("modulus:", x % y)
# Out:
# addition: 15
# subtraction: 5
# multiplication: 50
# division: 2.0
# modulus: 0

# %%
# Relational operators
a = 10
b = 5
print("a > b:",a > b)
print("a < b:",a < b)
print("a == b:",a == b)
print("a != b:",a != b)
print("a >= b:",a >= b)
print("a <= b:",a <= b)
# Out:
# a > b: True
# a < b: False
# a == b: False
# a != b: True
# a >= b: True
# a <= b: False

# %%
#assignment operators
a = 10
a += 5
print("a =", a)
# Out:
# a = 15

# %%
#logical operators
a = 10
b = 5

print(a > 5 and b < 10)
print(a > 15 or b < 10)
print(not(a > 5))
# Out:
# True
# True
# False

# %% [markdown]
# Datatypes

# %%
age = (1,2,3)
type(age)
# Out:
# tuple

# %%
age = {12,56}
type(age)
# Out:
# set

# %%
age = [2,8,0,9]
type(age)
# Out:
# list

# %%
age = 2.0
type(age)
# Out:
# float

# %%
age = "hello"
type(age)
# Out:
# str

# %%
fruits = ["apple", "banana", "cherry"]
numbers = (10, 20, 30)
type(fruits), type(numbers)
# Out:
# (list, tuple)

# %%
num = {10,20,30}
type(num)
# Out:
# set

# %%
#user-defined function
def add(a, b):
    return a + b

answer = add(10, 12)
print(answer)
# Out:
# 11890

# %%
#Calculator using function

# %%
def add(a, b):
    return a + b


def subtract(a, b):
    return a - b


def multiply(a, b):
    return a * b


def divide(a, b):
    return a / b


num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = int(input("Enter your choice: "))

if choice == 1:
    print("Answer:", add(num1, num2))

elif choice == 2:
    print("Answer:", subtract(num1, num2))

elif choice == 3:
    print("Answer:", multiply(num1, num2))

elif choice == 4:
    print("Answer:", divide(num1, num2))

else:
    print("Invalid choice")
# Out:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Answer: 0.5217391304347826

# %%
# Local and Global Variables and Global Keyword

# %%
x = 10  # Global variable

def change():
    global x

    x = 20          # Changing global x
    y = 50          # Local variable

    print("Inside function:")
    print("Global x =", x)
    print("Local y =", y)


change()

print("Outside function:")
print("Global x =", x)
# Out:
# Inside function:
# Global x = 20
# Local y = 50
# Outside function:
# Global x = 20

# %%
# Default argument

# %%
def greet(name = "aadi"):
    print("Hello",name)

greet()
    #   name = "aadi" is default argument
    # what if we provide a value

def greet(name = "aadi"):
    print("Hello",name)

greet("aaditya")

#the provided value replace the default value
# Out:
# Hello aadi
# Hello aaditya

# %%
# multiple parameter

def add(a, b):
    return a + b

answer = add(10, 20)

print(answer)
# Out:
# 30

# %%
# return value

# using print()
def add(a, b):
    print(a+b)

    answer = add(10 + 20) 
print(answer)


# using return
def add(a, b):
    return a+b

    answer = add(10 + 20) 
print(answer)
# Out:
# 30
# 30
