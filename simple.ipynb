# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
name = input("What is your name? ")
print(f"Hello, {name}!")
# Out:
# Hello, Aaditya!

# %%
for i in range(5):
    print(i+1)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
student = {
    "name":"xyz",
    "age":10,
    "grade":"A"
}
print(student["name"])
# Out:
# xyz

# %%
name = input("enter your name")
if name == 'sam':
    print('hello Sam')
else:
    print('hello dude')
    print('how are you')
# Out:
# hello Sam
